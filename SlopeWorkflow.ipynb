# %% [markdown]
# #**Here we show the workflow for evaluating slope in Python syntax**
# The link to official GDAL documentation: https://gdal.org/programs/gdaldem.html <br />
# A useful video on how to apply the GDAL slope function in Python:
# https://www.youtube.com/watch?v=5dDZeEXws9Q

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install rasterio
# Out:
# ...
#      |████████████████████████████████| 19.1MB 45.8MB/s
# ...

# %%
import rasterio as rio
import xarray as xr
import os
import subprocess
from osgeo import gdal

# %%
dem = #### Input tiff file to evaluate for slope
slp = gdal.DEMProcessing("slope.tif", dem, "slope", alg='Horn', computeEdges=True)
slpArray = slp.GetRasterBand(1).ReadAsArray()

# %%
"""
Example Output
"""
plt.figure(figsize=(10,10))
plt.imshow(slpArray)
plt.colorbar()
plt.show()
